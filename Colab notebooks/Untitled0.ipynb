# %%
n = 0
soma = 0
for i in ( range (1,5)):
  n = input ()
  if (n < 0):
    soma = soma + n
  else:
    print ('fnaknfka')

print ('soma', soma)
# Out:
# 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-3a7ad0faa13a> in <module>()
#       3 for i in range(1,5):
#       4   n = input ()
# ----> 5   if (n < 0):
#       6     soma = soma + n
#       7   else:
#
# TypeError: '<' not supported between instances of 'str' and 'int'
